# %% [markdown]
# # **Практическая работа 1. Источники данных. Извлечение данных**

# %% [markdown]
# ## **Задание 1.**

# %% [markdown]
# Работа на занятии (групповое выполнение задания).
# Задачи:
# - работа с данными из файла CSV и построение визуализации

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - парсинг веб-страницы (https://apidata.mos.ru/v1/datasets/60789/features?api_key=079dd1c5-bbd2-4db8-8419-2ae029f87ac8; используем идентификатор набора данных: 60789, а также свой код api) с помощью JSON;
# - парсинг веб-страницы с помощью Beautiful Soup;
# - получение данных из таблиц РСУБД и их визуализация;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - получение данных Parquet и их визуализация;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - построение верхнеуровневой архитектуры аналитического решения.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Задание 2.**

# %% [markdown]
# Парсинг веб-страниц с помощью Beautiful Soup и Pandas открытых источников данных, согласно варианта: ETF от FinEx — https://finex-etf.ru/products/ и построение визуализации

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Верхнеуровневая архитектура аналитического решения

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Задание 3.**

# %% [markdown]
# Парсинг коллекции данных на Портале открытых данных Правительства Москвы (при отсутствии доступа к Порталу https://rosstat.gov.ru/). Выделение показателей в наборе данных согласно варианта 5: Трудоустройство. и построение визуализации

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Верхнеуровневая архитектура аналитического решения

# %% [markdown]
# ![image.png](data:image/png;base64,...)
